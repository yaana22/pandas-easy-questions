# %% [markdown]
#  Pandas Practice — Part 1 (Questions 1–20)

# %%
import pandas as pd
import numpy as np
print('pandas version:', pd.__version__)
# Out:
# pandas version: 2.2.2

# %% [markdown]
# ### Q1: Create a pandas Series from [10, 20, 30, 40, 50].

# %%
s1 = pd.Series([10, 20, 30, 40, 50])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ### Q2: Create a pandas Series [100,200,300,400] with index ['a','b','c','d'].

# %%
s2 = pd.Series([100,200,300,400], index=['a','b','c','d'])
s2
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# ### Q3: Create a DataFrame with Name ['Aniket','Priya','Rohan'] and Age [28,24,22].

# %%
df = pd.DataFrame({'Name':['Aniket','Priya','Rohan'], 'Age':[28,24,22]})
df
# Out:
#      Name  Age
# 0  Aniket   28
# 1   Priya   24
# 2   Rohan   22

# %% [markdown]
# ### Q4: Create a DataFrame from list [['Alice',25],['Bob',30],['Charlie',35]] with columns ['Name','Age'].

# %%
df2 = pd.DataFrame([['Alice',25],['Bob',30],['Charlie',35]], columns=['Name','Age'])
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ### Q5: Create DataFrame {'col1':[1,2], 'col2':[3,4]} with index ['row1','row2'].

# %%
df3 = pd.DataFrame({'col1':[1,2], 'col2':[3,4]}, index=['row1','row2'])
df3
# Out:
#       col1  col2
# row1     1     3
# row2     2     4

# %% [markdown]
# ### Q6: Create an empty DataFrame of shape (5,3) (all NaN) with columns ['col1','col2','col3'].

# %%
df_nan = pd.DataFrame(index=range(5), columns=['col1','col2','col3'])
df_nan
# Out:
#   col1 col2 col3
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN

# %% [markdown]
# ### Q7: Create a 4x4 DataFrame of random integers 0–100 with columns 'A','B','C','D'.

# %%
df_rand = pd.DataFrame(np.random.randint(0,101,size=(4,4)), columns=list('ABCD'))
df_rand
# Out:
#      A   B   C   D
# 0   33  33  94  94
# 1   64  45  26  27
# 2   62  73  84  77
# 3  100  42  50  17

# %% [markdown]
# ### Q8: Create a Series from dictionary {'apples':40, 'bananas':50, 'cherries':80}.

# %%
s_dict = pd.Series({'apples':40, 'bananas':50, 'cherries':80})
s_dict
# Out:
# apples      40
# bananas     50
# cherries    80
# dtype: int64

# %% [markdown]
# ### Q9: Create a 3x3 NumPy array with arange(9) and convert to DataFrame.

# %%
arr = np.arange(9).reshape(3,3)
df_from_np = pd.DataFrame(arr)
df_from_np
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %% [markdown]
# ### Q10: Make a copy of DataFrame df (from Q3) into df_copy.

# %%
df_copy = df.copy()
df_copy
# Out:
#      Name  Age
# 0  Aniket   28
# 1   Priya   24
# 2   Rohan   22

# %% [markdown]
# ### Q11: Read a CSV file named 'yourfile.csv' into DataFrame df (example).

# %%
# Example (file must exist in runtime). Uncomment if you have the file:
# df = pd.read_csv('yourfile.csv')
print('Use pd.read_csv with your file path')
# Out:
# Use pd.read_csv with your file path

# %% [markdown]
# ### Q12: Show last 3 rows of df (if it exists).

# %%
try:
    display(df.tail(3))
except NameError:
    print('df not defined in this runtime; create a DataFrame first')
# Out:
#      Name  Age
# 0  Aniket   28
# 1   Priya   24
# 2   Rohan   22

# %% [markdown]
# ### Q13: Get shape of df (rows, columns).

# %%
try:
    print('shape =', df.shape)
except NameError:
    print('df not defined; create a DataFrame first')
# Out:
# shape = (3, 2)

# %% [markdown]
# ### Q14: Get list of columns of df.

# %%
try:
    print(df.columns.tolist())
except NameError:
    print('df not defined')
# Out:
# ['Name', 'Age']

# %% [markdown]
# ### Q15: Show index of df.

# %%
try:
    print(df.index)
except NameError:
    print('df not defined')
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# ### Q16: Show dtypes of df.

# %%
try:
    print(df.dtypes)
except NameError:
    print('df not defined')
# Out:
# Name    object
# Age      int64
# dtype: object

# %% [markdown]
# ### Q17: Display info() for df.

# %%
try:
    df.info()
except NameError:
    print('df not defined')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %% [markdown]
# ### Q18: Count unique values in column 'City' (example).

# %%
print('Example: create a sample df with City and count unique')
_sample = pd.DataFrame({'City':['NY','LA','NY','LDN']})
print(_sample['City'].nunique())
# Out:
# Example: create a sample df with City and count unique
# 3

# %% [markdown]
# ### Q19: Show unique values in column 'City' (example).

# %%
print('Unique values:')
print(_sample['City'].unique())
# Out:
# Unique values:
# ['NY' 'LA' 'LDN']

# %% [markdown]
# ### Q20: Show descriptive statistics (describe()) for numeric columns of df (example).

# %%
print('Example describe on sample df:')
_sample2 = pd.DataFrame({'A':[1,2,3,4], 'B':[0.5, 0.75, 1.25, 2.0]})
print(_sample2.describe())
# Out:
# Example describe on sample df:
#               A         B
# count  4.000000  4.000000
# mean   2.500000  1.125000
# std    1.290994  0.661438
# min    1.000000  0.500000
# 25%    1.750000  0.687500
# 50%    2.500000  1.000000
# 75%    3.250000  1.437500
# max    4.000000  2.000000
